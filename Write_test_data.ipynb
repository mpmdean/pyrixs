# %%
import numpy as np
import pandas as pd

import os, glob

from collections import OrderedDict

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib nbagg

# %%
plt.figure()
ax1 = plt.subplot(111)
spectra = OrderedDict()

cens = np.linspace(48, 52, 20)
peaks = 1 + np.random.rand(len(cens))

x = np.arange(200)
for i, (cen, peak) in enumerate(zip(cens, peaks)): 
    y = peak*np.exp(-(x-cen)**2 / 20) + np.random.rand(len(x))  + 2*peak*np.exp(-(x-100)**2 / 20) 
    spectra.update({"{:0>4d}".format(i): pd.Series(y, index=x, name="{:0>4d}".format(i))})

for name, spectrum in spectra.items():
    spectrum.plot()

plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
for name, spectrum in spectra.items():
    x = spectrum.index
    y = spectrum.values
    M = np.vstack((x,y,y)).transpose()
    np.savetxt('test_data/{}.txt'.format(name), M)

# %%
plt.figure()
spectrum[np.logical_and(spectrum.index>70, spectrum.index<80)].values
# Out:
# <img src="data:image/png;base64,...">
# array([ 0.78342392,  0.85031353,  0.49618657,  0.4630203 ,  0.94031956,
#         0.48694461,  0.73620213,  0.87887173,  0.44883448])
