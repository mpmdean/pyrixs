# %%
import process2d
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib nbagg
import lmfit

# %%
process2d.run_test()
# Out:
# No data found: Simulate an image
# Curvature is 5.7938298626645014e-08 x^2 + -0.01980215527616777 x + 500.0
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# Resolution is 3.1185064452444538
# (<matplotlib.axes._subplots.AxesSubplot at 0x117643da0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11b387358>)

# %%
plt.title?
