# %%
import numpy as np
import matplotlib.pyplot as plt

from process1d import *

# %matplotlib nbagg

# %%
from pyrixs import process1d
process1d.run_test()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# No spectra loaded
# Making fake spectra
# (<matplotlib.axes._subplots.AxesSubplot at 0x117602a58>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x119a9b240>)

# %%
plt.figure?
